# %%
# Importing seaborn
import seaborn as sns;

# %%
# Get list names of dummy data you auto import from seaborn
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# Using seaborn to import dammy data (But You can use or import any data you want)
taxisData = sns.load_dataset('taxis')
# type(data)
# data.shape
taxisData
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
# To show correlation between data fields in pandas
taxisData.corr()
# Out:
# C:\Users\jmbilizi\AppData\Local\Temp\ipykernel_26368\2511415131.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   taxisData.corr()
#             passengers  distance      fare       tip     tolls     total
# passengers    1.000000  0.009411  0.007637  0.021099 -0.002903  0.015708
# distance      0.009411  1.000000  0.920108  0.452589  0.635267  0.904676
# fare          0.007637  0.920108  1.000000  0.488612  0.609307  0.974358
# tip           0.021099  0.452589  0.488612  1.000000  0.413619  0.646186
# tolls        -0.002903  0.635267  0.609307  0.413619  1.000000  0.683142
# total         0.015708  0.904676  0.974358  0.646186  0.683142  1.000000

# %%
# Chart with correlation between data fields in seaborn. annot (show numbers or no), cmap('YlGnBu' or 'icefire', etc...)
sns.heatmap(taxisData.corr(), annot=True, cmap="coolwarm")
# Out:
# C:\Users\jmbilizi\AppData\Local\Temp\ipykernel_26368\2003541834.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(taxisData.corr(), annot=True, cmap="coolwarm")
# <Axes: >

# %%
# Lets use seaborn to display chart (https://seaborn.pydata.org/examples/index.html)
sns.scatterplot(x="passengers", y="total", data=taxisData, hue="pickup_borough", size="distance", palette="YlGnBu")
# Out:
# <Axes: xlabel='passengers', ylabel='total'>

# %%
sns.histplot(taxisData["total"], kde=True, bins=15)
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %%
# barplot or boxplot chart
sns.boxplot(data=taxisData, x="pickup_borough", y="total", palette="YlGnBu")
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
# barplot chart
sns.barplot(data=taxisData, x="pickup_borough", y="total", palette="YlGnBu")
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
# jointplot --> is a regretional chart that shows you where the concentration of values are.
sns.jointplot(data=taxisData, x="total", y="distance", kind="kde", fill=True)

# %%
# pairplot
sns.pairplot(taxisData.select_dtypes(["number"]), hue="total")

# %%
# clustering dataset chart  --> accept numeric only dataset (Great to look at when performing unsupervised learning)
numericOnlyTaxisData = taxisData.drop(['pickup', 'dropoff', 'color', 'payment', 'pickup_zone', 'dropoff_zone', 'pickup_borough', 'dropoff_borough'], axis=1)
sns.clustermap(numericOnlyTaxisData)
# Out:
# c:\Users\jmbilizi\AppData\Local\anaconda3\lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
