# %% [markdown]
# ## Filtering DataFrame

# %%
# Here is how to import pandas in your project
import pandas as pd;

# %%
df = pd.read_csv('../../titanic.csv', header=0)

# %% [markdown]
# 1. Using Just Boolean Selection
#
# Consiste of creating a copy of a given colomn with a value of true or false in each row. Then use those values to filter.

# %%
# Example of bolean selection
data = df
data['Sex'] == 'female'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 891    False
# 892     True
# 893     True
# 894    False
# 895    False
# Name: Sex, Length: 896, dtype: bool

# %%
# Filtering table based of the bolean selection condition
data = df
femaleSex = data['Sex'] == 'female'
data[femaleSex]
# Out:
#      PassengerId  Survived  Pclass  \
# 3              2         1       1
# 4              3         1       3
# 5              4         1       1
# 13             9         1       3
# 14            10         1       2
# ..           ...       ...     ...
# 885          881         1       2
# 887          883         0       3
# 890          886         0       3
# 892          888         1       1
# 893          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 3    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                               Heikkinen, Miss. Laina  female  26.0      0
# 5         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 13   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 14                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Filter all passengers below the age of 16
data = df
data[data['Age'] > 60]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 38            34         0       2                      Wheadon, Mr. Edward H
# 59            55         0       1             Ostby, Mr. Engelhart Cornelius
# 101           97         0       1                  Goldschmidt, Mr. George B
# 121          117         0       3                       Connors, Mr. Patrick
# 175          171         0       1                  Van der hoef, Mr. Wyckoff
# 257          253         0       1                  Stead, Mr. William Thomas
# 280          276         1       1          Andrews, Miss. Kornelia Theodosia
# 285          281         0       3                           Duane, Mr. Frank
# 331          327         0       3                  Nysveen, Mr. Johan Hansen
# 443          439         0       1                          Fortune, Mr. Mark
# 461          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
# Multi filter. Filter all passenger above the age of 60 AND that are female
data = df
data[(data['Age'] > 60) & (data['Sex'] == 'female')]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 280          276         1       1          Andrews, Miss. Kornelia Theodosia
# 488          484         1       3                     Turkula, Mrs. (Hedwig)
# 834          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 280  female  63.0      1      0   13502  77.9583    D7        S
# 488  female  63.0      0      0    4134   9.5875   NaN        S
# 834  female  62.0      0      0  113572  80.0000   B28      NaN

# %%
# Multi filter. Filter all passenger above the age of 60 OR that are female
data = df
data[(data['Age'] > 60) | (data['Sex'] == 'female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 3              2         1       1
# 4              3         1       3
# 5              4         1       1
# 13             9         1       3
# 14            10         1       2
# ..           ...       ...     ...
# 885          881         1       2
# 887          883         0       3
# 890          886         0       3
# 892          888         1       1
# 893          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 3    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                               Heikkinen, Miss. Laina  female  26.0      0
# 5         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 13   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 14                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 2. Using The Loc Method

# %%
# Multi filter rows and reduced columnsusing Loc method
data = df
condition = (data['Age'] > 75) | (data['Sex'] <= 'female') | (data['Age'] <= 20)
data.loc[condition, ['Name', 'Age', 'Sex', 'Fare']]
# Out:
#                                                   Name   Age     Sex     Fare
# 3    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female  71.2833
# 4                               Heikkinen, Miss. Laina  26.0  female   7.9250
# 5         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female  53.1000
# 12                      Palsson, Master. Gosta Leonard   2.0    male  21.0750
# 13   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female  11.1333
# ..                                                 ...   ...     ...      ...
# 885       Shelley, Mrs. William (Imanita Parrish Hall)  25.0  female  26.0000
# 887                       Dahlberg, Miss. Gerda Ulrika  22.0  female  10.5167
# 890               Rice, Mrs. William (Margaret Norton)  39.0  female  29.1250
# 892                       Graham, Miss. Margaret Edith  19.0  female  30.0000
# 893           Johnston, Miss. Catherine Helen "Carrie"   NaN  female  23.4500
#
# [417 rows x 4 columns]
